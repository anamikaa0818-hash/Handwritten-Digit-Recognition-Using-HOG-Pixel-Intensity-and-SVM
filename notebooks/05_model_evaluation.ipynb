# %%
# Cell 1: Setup
import sys
sys.path.append('../src')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from model_evaluation import ModelEvaluator
import pickle

# %% [markdown]
# Cell 2: Load Models and Features
# (Load from previous notebook or from saved files)
# models = {...}  # dictionary of trained models
# features_test, y_test = ...

# %%
# Cell 3: Initialize Evaluator and Evaluate All Models
evaluator = ModelEvaluator()
evaluator.evaluate_all_models(models, features_test, y_test)

# Cell 4: Create Comparison Table
df_comparison = evaluator.compare_models()
df_comparison.to_csv('../data/model_comparison.csv', index=False)

# Cell 5: Plot Confusion Matrices
evaluator.plot_confusion_matrices()

# Cell 6: Plot Per-Digit Accuracy
evaluator.plot_per_digit_accuracy()

# Cell 7: Plot Model Comparison
evaluator.plot_model_comparison_bar()

# Cell 8: Feature Combination Analysis
# Out:
# ============================================================
# MODEL EVALUATION ON TEST SET
# ============================================================
#
# === SVM ===
# Accuracy:  0.9653
# Precision: 0.9653
# Recall:    0.9653
# F1-Score:  0.9653
#
# === KNN ===
# Accuracy:  0.9798
# Precision: 0.9800
# Recall:    0.9798
# F1-Score:  0.9798
#
# === LogisticRegression ===
# Accuracy:  0.9689
# Precision: 0.9689
# Recall:    0.9689
# F1-Score:  0.9689
#
# === RandomForest ===
# Accuracy:  0.9639
# Precision: 0.9639
# Recall:    0.9639
# F1-Score:  0.9639
#
# === SVM_Tuned ===
# Accuracy:  0.9651
# Precision: 0.9652
# Recall:    0.9651
# F1-Score:  0.9651
#
# ======================================================================
# MODEL COMPARISON
# ======================================================================
#              Model  Accuracy  Precision   Recall  F1-Score
#                KNN  0.979786   0.979958 0.979786  0.979779
# LogisticRegression  0.968929   0.968938 0.968929  0.968925
#                SVM  0.965286   0.965292 0.965286  0.965272
#          SVM_Tuned  0.965143   0.965150 0.965143  0.965130
#       RandomForest  0.963929   0.963919 0.963929  0.963896
# ======================================================================
# MODEL COMPARISON
# ======================================================================
#              Model  Accuracy  Precision   Recall  F1-Score
#                KNN  0.979786   0.979958 0.979786  0.979779
# LogisticRegression  0.968929   0.968938 0.968929  0.968925
#                SVM  0.965286   0.965292 0.965286  0.965272
#          SVM_Tuned  0.965143   0.965150 0.965143  0.965130
#       RandomForest  0.963929   0.963919 0.963929  0.963896
